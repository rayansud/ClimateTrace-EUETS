# %% [markdown]
# # Imports and Data Read

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from geopy import distance
from sklearn.neighbors import BallTree
from tqdm import tqdm
import plotly.express as px
import re
from haversine import haversine_vector, Unit

# %%
ct_data = pd.read_csv('CT_asset_cement_emissions.csv')
ets_data = pd.read_csv('EUETS_acquiring_accounts_bytransactions.csv')

cols = ['Acquiring.Holder.MainAddressLine', 'Acquiring.Holder.SecondaryAddressLine', 'Acquiring.Holder.City','Acquiring.Holder.ZipCode','Acquiring.Holder.Country']
ets_data['Address'] = ets_data[cols].apply(lambda row: ', '.join(row.values.astype(str)), axis=1)
ets_data['Address'] = ets_data['Address'].str.replace('nan, ','')
ct_data['st_astext'] = ct_data['st_astext'].astype(str)

ct_data[['lng', 'lat']] = ct_data['st_astext'].str.split(' ', 1, expand=True)
ct_data['lng'] = ct_data['lng'].str.replace('POINT(','',regex=False)
ct_data['lat'] = ct_data['lat'].str.replace(')','',regex=False)
ct_data['lat'] = ct_data['lat'].astype(float)
ct_data['lng'] = ct_data['lng'].astype(float)
codes = pd.read_excel('CountryCodes.xlsx')
# Out:
# /var/folders/h0/rfb20rk90qz0tdgv08kqcyrw0000gn/T/ipykernel_65515/1076258205.py:2: DtypeWarning: Columns (10,11,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   ets_data = pd.read_csv('EUETS_acquiring_accounts_bytransactions.csv')
# /var/folders/h0/rfb20rk90qz0tdgv08kqcyrw0000gn/T/ipykernel_65515/1076258205.py:9: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   ct_data[['lng', 'lat']] = ct_data['st_astext'].str.split(' ', 1, expand=True)

# %% [markdown]
# # Filtering CT data for countries that are in ETS data

# %%
ct_data_2digcode = pd.merge(ct_data,codes,how='left',left_on='iso3_country',right_on='Code3')
ct_data_filterETS = ct_data_2digcode[ct_data_2digcode['Code2'].isin(ets_data['Acquiring.Holder.CountryCode'].unique())]
ct_data_filterETS.to_csv('filteredETS_CTdata.csv')
# Out:
#         asset_id iso3_country original_inventory_sector           start_time  \
# 0        1754169          BRA                    cement  2016-03-01 00:00:00
# 1        1754169          BRA                    cement  2016-04-01 00:00:00
# 2        1754169          BRA                    cement  2016-05-01 00:00:00
# 3        1754169          BRA                    cement  2016-06-01 00:00:00
# 4        1754169          BRA                    cement  2016-07-01 00:00:00
# ...          ...          ...                       ...                  ...
# 992195   1756298          ZAF                    cement  2015-02-01 00:00:00
# 992196   1756298          ZAF                    cement  2015-02-01 00:00:00
# 992197   1756298          ZAF                    cement  2015-02-01 00:00:00
# 992198   1756298          ZAF                    cement  2015-02-01 00:00:00
# 992199   1756298          ZAF                    cement  2015-03-01 00:00:00
#
#                    end_time temporal_granularity         gas  \
# 0       2016-03-31 00:00:00                month         ch4
# 1       2016-04-30 00:00:00                month         ch4
# 2       2016-05-31 00:00:00                month         ch4
# 3       2016-06-30 00:00:00                month         ch4
# 4       2016-07-31 00:00:00                month         ch4
# ...                     ...                  ...         ...
# 992195  2015-02-28 00:00:00                month         co2
# 992196  2015-02-28 00:00:00                month         n2o
# 992197  2015-02-28 00:00:00                month  co2e_100yr
# 992198  2015-02-28 00:00:00                month   co2e_20yr
# 992199  2015-03-31 00:00:00                month         co2
#
#         emissions_quantity  emissions_factor       emissions_factor_units  \
# 0                        0               NaN  tonnes_gas_per_tonnesCement
# 1                        0               NaN  tonnes_gas_per_tonnesCement
# 2                        0               NaN  tonnes_gas_per_tonnesCement
# 3                        0               NaN  tonnes_gas_per_tonnesCement
# 4                        0               NaN  tonnes_gas_per_tonnesCement
# ...                    ...               ...                          ...
# 992195               73007          0.811607  tonnes_gas_per_tonnesCement
# 992196                   0               NaN  tonnes_gas_per_tonnesCement
# 992197               73007               NaN  tonnes_gas_per_tonnesCement
# 992198               73007               NaN  tonnes_gas_per_tonnesCement
# 992199               87417          0.811607  tonnes_gas_per_tonnesCement
#
#         ...                created_date modified_date  \
# 0       ...  2022-09-05 15:22:06.555594           NaN
# 1       ...  2022-09-05 15:22:06.555594           NaN
# 2       ...  2022-09-05 15:22:06.555594           NaN
# 3       ...  2022-09-05 15:22:06.555594           NaN
# 4       ...  2022-09-05 15:22:06.555594           NaN
# ...     ...                         ...           ...
# 992195  ...  2022-09-05 15:22:07.177031           NaN
# 992196  ...  2022-09-05 15:22:07.177031           NaN
# 992197  ...  2022-09-05 15:22:07.177031           NaN
# 992198  ...  2022-09-05 15:22:07.177031           NaN
# 992199  ...  2022-09-05 15:22:07.177031           NaN
#
#                              asset_name asset_type  \
# 0         Cantagalo cement plant (0046)        Dry
# 1         Cantagalo cement plant (0046)        Dry
# 2         Cantagalo cement plant (0046)        Dry
# 3         Cantagalo cement plant (0046)        Dry
# 4         Cantagalo cement plant (0046)        Dry
# ...                                 ...        ...
# 992195  Johannesburg South cement plant        NaN
# 992196  Johannesburg South cement plant        NaN
# 992197  Johannesburg South cement plant        NaN
# 992198  Johannesburg South cement plant        NaN
# 992199  Johannesburg South cement plant        NaN
#
#                            st_astext        lng        lat       Country  \
# 0       POINT(-42.271287 -21.941689) -42.271287 -21.941689        Brazil
# 1       POINT(-42.271287 -21.941689) -42.271287 -21.941689        Brazil
# 2       POINT(-42.271287 -21.941689) -42.271287 -21.941689        Brazil
# 3       POINT(-42.271287 -21.941689) -42.271287 -21.941689        Brazil
# 4       POINT(-42.271287 -21.941689) -42.271287 -21.941689        Brazil
# ...                              ...        ...        ...           ...
# 992195   POINT(28.121422 -26.223458)  28.121422 -26.223458  South Africa
# 992196   POINT(28.121422 -26.223458)  28.121422 -26.223458  South Africa
# 992197   POINT(28.121422 -26.223458)  28.121422 -26.223458  South Africa
# 992198   POINT(28.121422 -26.223458)  28.121422 -26.223458  South Africa
# 992199   POINT(28.121422 -26.223458)  28.121422 -26.223458  South Africa
#
#         Code2  Code3
# 0          BR    BRA
# 1          BR    BRA
# 2          BR    BRA
# 3          BR    BRA
# 4          BR    BRA
# ...       ...    ...
# 992195     ZA    ZAF
# 992196     ZA    ZAF
# 992197     ZA    ZAF
# 992198     ZA    ZAF
# 992199     ZA    ZAF
#
# [992200 rows x 23 columns]

# %% [markdown]
# # Geocoding all ETS addresses to Lat,Lng

# %%
locator = Nominatim(user_agent="myGeocoder")
unique_locs=ets_data['Address'].unique()

latlngs = np.zeros((len(unique_locs),2))

for idx,loc in enumerate(tqdm(unique_locs)):
    try:
        gc = locator.geocode(loc)
        latlngs[idx,0]=gc.latitude
        latlngs[idx,1]=gc.longitude
    except:
        latlngs[idx,0]=91
        latlngs[idx,1]=91
#ets_data['point'] = ets_data['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#ets_data[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)

# %%
np.savetxt("GeocodedETSLatlngs.csv", latlngs, delimiter=",")

# %%
latlngs = np.loadtxt('GeocodedETSLatlngs.csv',delimiter=',')
fig = px.scatter_geo(lat=latlngs[:,0], lon=latlngs[:,1],hover_name=unique_locs)

# %% [markdown]
# ## TODO:
# * Reverse geocode all CT points
# * Match CT and ETS on country AND zip code
# * Generate distances between all matches pairs
# * For distances below 5km

# %% [markdown]
# # Reverse Geocode all CT points to get Country,Zip

# %%
ct_addresses = np.zeros(len(ct_data.lat),dtype=str)

for idx,loc in enumerate(tqdm(ct_data.lat)):
    try:
        ct_addresses[idx]=(locator.reverse(str(ct_data.lat[idx])+','+str(ct_data.lng[idx])))
    except:
        ct_addresses[idx]='NA'
    print(ct_addresses)
    break
#ets_data['point'] = ets_data['location'].apply(lambda loc: tuple(loc.point) if loc else None)
#ets_data[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)
# Out:
#   0%|                                                                                                                                             | 0/992200 [00:00<?, ?it/s]
# ['N' '' '' ... '' '' '']

# %% [markdown]
# # Generate distance between all pairs of CT lat,lng and ETS lat,lng in same country

# %% [markdown]
# ## TODO:
# * Split CT and ETS into country blocks
# * For each matching country block, calculate haversine

# %%
country_blocks = []

all_countries_ets = ct_data_filterETS['Code2'].unique()
all_countries_ct = ct_data_filterETS['Code2'].unique()

# %%
haversine_vector(ETS_countryblock, CT_countryblock, Unit.KILOMETERS, comb=True)
len(ct_data_filterETS)*len(latlngs)
# Out:
# 923560

# %%
# Out:
# 13201
